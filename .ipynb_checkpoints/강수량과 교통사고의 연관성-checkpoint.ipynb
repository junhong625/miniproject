# %% [markdown]
# ## 강수량 데이터

# %%
## 강수량 전체데이터 전처리

import csv
import pandas as pd

df = pd.read_csv('강수량.csv', encoding='euc-kr', header=7) 
# 그냥 불러왔을 때 CSV파일에 쓸데 없는 데이터 때문에 에러가 나니 header=7을 통해 csv파일의 7번째 줄부터 데이터를 가져온다.

df = df.drop(['지점명'], axis=1)
df = df.drop(['\t지점번호'], axis=1)
df = df.drop(['1시간최다강수량(mm)'], axis=1)
df = df.drop(['1시간최다강수량시각'], axis=1)
df = df.drop(['Unnamed: 6'], axis=1)
# 내가 원하는 데이터와 상관없는 데이터들은 삭제하여 보기 좋게 데이터를 고친다. 

#df = df.fillna(0)
df = df.dropna()
# df파일에 dropna 메소드를 통해 NA 즉, 데이터가 들어있지 않은 부분의 행을 삭제한다.

df.reset_index(inplace=True)
df = df.drop(['index'], axis=1) 
# reset_index 메소드를 실행하면서 생겨난 index column을 삭제한다.

df.rename(columns = {'일시':'날짜'}, inplace=True)
df = df.set_index(['날짜'])
# 보기 좋게 index를 날짜로 설정한다

# %%
H = df['강수량(mm)'] >= 80 # 강수량이 80mm 이상인 데이터를 H로 저장 
df[H]
# Out:
#             강수량(mm)
# 날짜
# 2016-07-01    108.5
# 2016-07-05    100.5
# 2017-07-02     92.0
# 2017-07-10    144.5
# 2017-07-23    133.5
# 2017-08-15     93.5
# 2017-08-20    124.5
# 2018-05-17     83.0
# 2018-07-01     83.5
# 2018-08-28     96.5
# 2020-07-23    103.1
# 2020-08-03    102.6
# 2020-08-11     97.0
# 2020-11-19     86.9

# %%
M = df['강수량(mm)'] < 80 # 강수량이 80mm 미만인 데이터
M = df[M]
M = df['강수량(mm)'] > 0
df[M]
# Out:
#             강수량(mm)
# 날짜
# 2016-01-13      0.4
# 2016-01-16      0.1
# 2016-01-18      0.2
# 2016-01-26      0.3
# 2016-02-11      0.1
# ...             ...
# 2020-11-22      4.8
# 2020-12-13      2.9
# 2020-12-18      0.2
# 2020-12-28      1.3
# 2020-12-29      0.2
#
# [519 rows x 1 columns]

# %%
Z = df['강수량(mm)'] == 0.0 # 강수량이 0mm인 데이터
df[Z]
# Out:
#             강수량(mm)
# 날짜
# 2016-01-14      0.0
# 2016-01-23      0.0
# 2016-02-15      0.0
# 2016-02-22      0.0
# 2016-02-26      0.0
# ...             ...
# 2020-12-10      0.0
# 2020-12-17      0.0
# 2020-12-23      0.0
# 2020-12-27      0.0
# 2020-12-31      0.0
#
# [185 rows x 1 columns]

# %% [markdown]
# ## 교통사고 데이터

# %%
data = pd.read_csv('accident.csv', sep=',')
data = data.drop(['Unnamed: 0'], axis=1)
data = data.dropna()
data = data.reset_index()
data = data.drop(['index'], axis=1)

# 데이터를 보기 수정하기 용이하게 만들기 위해 사고년도, 사고월, 사고일 column을 str으로 변경
data = data.astype({'사고년도': 'int'}) # 사고년도가 float로 되어있어 2016.0 이런식으로 나타내는걸 바꾸기 위해 int타입으로 바꿔 2016으로 출력되게 만들기 위함
data = data.astype({'사고년도': 'str'})
data = data.astype({'사고월': 'str'})
data = data.astype({'사고일': 'str'})

data
# Out:
#       사고년도  사고월  사고일    구분    구분값
# 0     2016  01월  01일  사고건수   66.0
# 1     2016  01월  01일  사망자수    0.0
# 2     2016  01월  01일  부상자수   98.0
# 3     2016  01월  02일  사고건수   79.0
# 4     2016  01월  02일  사망자수    1.0
# ...    ...  ...  ...   ...    ...
# 5476  2020  12월  30일  사망자수    2.0
# 5477  2020  12월  30일  부상자수  116.0
# 5478  2020  12월  31일  사고건수   98.0
# 5479  2020  12월  31일  사망자수    0.0
# 5480  2020  12월  31일  부상자수  126.0
#
# [5481 rows x 5 columns]

# %%
year = []
for i in range(len(data)):
    year.append(data['사고년도'][i]) # 년도 데이터를 저장

month = []
for i in range(len(data)):
    month.append(data['사고월'][i][0:2]) # 월 데이터를 숫자만 잘라서 저장
    
day = []
for i in range(len(data)):
    day.append(data['사고일'][i][0:2]) # 일 데이터를 숫자만 잘라서 저장
    
date = []
for i in range(len(data)):
    date.append(str(year[i])+'-'+str(month[i])+'-'+str(day[i])) # 년도, 월, 일 데이터를 합쳐서 0000-00-00으로 표시되도록 합침

for i in range(len(data)):
    data['사고년도'][i] = date[i] # '사고년도' column의 데이터를 date로 모두 변경

data = data.drop(['사고월'], axis=1) # 필요없는 사고월과 사고일의 column 데이터들을 삭제
data = data.drop(['사고일'], axis=1)

data.rename(columns = {'사고년도':'날짜'}, inplace=True) # 사고년도 column의 이름을 날짜로 변경
data
# Out:
# C:\Temp/ipykernel_15672/2102841706.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['사고년도'][i] = date[i] # '사고년도' column의 데이터를 date로 모두 변경
#               날짜    구분    구분값
# 0     2016-01-01  사고건수   66.0
# 1     2016-01-01  사망자수    0.0
# 2     2016-01-01  부상자수   98.0
# 3     2016-01-02  사고건수   79.0
# 4     2016-01-02  사망자수    1.0
# ...          ...   ...    ...
# 5476  2020-12-30  사망자수    2.0
# 5477  2020-12-30  부상자수  116.0
# 5478  2020-12-31  사고건수   98.0
# 5479  2020-12-31  사망자수    0.0
# 5480  2020-12-31  부상자수  126.0
#
# [5481 rows x 3 columns]

# %%
A = [] ## 사고건수 리스트
for i in range(len(data)):
    if data['구분'][i] == '사고건수':
        A.append(data['구분값'][i])
        
B = [] ## 사망자수 리스트
for i in range(len(data)):
    if data['구분'][i] == '사망자수':
        B.append(data['구분값'][i])
        
C = [] ## 부상자수 리스트
for i in range(len(data)):
    if data['구분'][i] == '부상자수':
        C.append(data['구분값'][i])
        
data = data.drop_duplicates(['날짜']) # 날짜 column데이터들 중 중복되는 데이터들 삭제

# %%
data = data.drop(['구분'],axis=1) # 사고건수, 사망자수, 부상자수 데이터들을 따로 집어넣을 것이기 때문에 필요없는 데이터 삭제
data = data.drop(['구분값'],axis=1)

# %%
data['사고건수'] = A # data에 사고건수라는 이름의 컬럼을 A데이터를 집어넣어 생성
data['사망자수'] = B
data['부상자수'] = C
data
# Out:
#               날짜   사고건수  사망자수   부상자수
# 0     2016-01-01   66.0   0.0   98.0
# 3     2016-01-02   79.0   1.0  116.0
# 6     2016-01-03   75.0   0.0  118.0
# 9     2016-01-04  107.0   0.0  165.0
# 12    2016-01-05   92.0   0.0  146.0
# ...          ...    ...   ...    ...
# 5466  2020-12-27   40.0   0.0   55.0
# 5469  2020-12-28   81.0   0.0  110.0
# 5472  2020-12-29   71.0   0.0   95.0
# 5475  2020-12-30   89.0   2.0  116.0
# 5478  2020-12-31   98.0   0.0  126.0
#
# [1827 rows x 4 columns]

# %%
data = data.set_index(['날짜']) # 날짜를 index로 변경
accident = data

# %%
accident
# Out:
#              사고건수  사망자수   부상자수
# 날짜
# 2016-01-01   66.0   0.0   98.0
# 2016-01-02   79.0   1.0  116.0
# 2016-01-03   75.0   0.0  118.0
# 2016-01-04  107.0   0.0  165.0
# 2016-01-05   92.0   0.0  146.0
# ...           ...   ...    ...
# 2020-12-27   40.0   0.0   55.0
# 2020-12-28   81.0   0.0  110.0
# 2020-12-29   71.0   0.0   95.0
# 2020-12-30   89.0   2.0  116.0
# 2020-12-31   98.0   0.0  126.0
#
# [1827 rows x 3 columns]

# %% [markdown]
# ## 강수량과 교통사고 발생수의 연관성 찾기

# %%
z = []
for i in df[Z].index : # 강수량이 0mm인 데이터들을 모아둔 Z의 인덱스와 accident의 인덱스를 비교한다. 즉, 두 데이터에서 날짜(인덱스)가 같은 날들의 데이터만 뽑아내서 z로 저장한다.
    for j in accident.index :
        if i == j:
            z.append(accident.loc[j]) # .loc[]를 통해 내가 지정한 index에 해당하는 값으 가져올 수 있다.
            
m = []
for i in df[M].index :
    for j in accident.index :
        if i == j:
            m.append(accident.loc[j])
        
h = []
for i in df[H].index :
    for j in accident.index :
        if i == j:
            h.append(accident.loc[j])

# %%
# 강수량이 80mm 이상인 날

accident_total = 0
death_total = 0
injury_total = 0
for i in range(len(h)):
    accident_total += h[i]['사고건수']
    death_total += h[i]['사망자수']
    injury_total += h[i]['부상자수']

print(accident_total/len(h)) # 평균 사고건수
print(death_total / len(h)) # 평균 사망자수
print(injury_total / len(h)) # 평균 부상자수
# Out:
# 1534.0
# 109.57142857142857
# 9.0
# 0.6428571428571429
# 2196.0
# 156.85714285714286

# %%
# 강수량이 0mm인 날

zero_accident_total = 0
zero_death_total = 0
zero_injury_total = 0
for i in range(len(z)):
    zero_accident_total += z[i]['사고건수']
    zero_death_total += z[i]['사망자수']
    zero_injury_total += z[i]['부상자수']

print(zero_accident_total/len(z)) # 평균 사고건수
print(zero_death_total / len(z)) # 평균 사망자수
print(zero_injury_total / len(z)) # 평균 부상자수
# Out:
# 18905.0
# 102.1891891891892
# 175.0
# 0.9459459459459459
# 25852.0
# 139.74054054054054

# %%
# 강수량이 80mm 미만인 날

Middle_accident_total = 0
Middle_death_total = 0
Middle_injury_total = 0
for i in range(len(m)):
    Middle_accident_total += m[i]['사고건수'] 
    Middle_death_total += m[i]['사망자수']
    Middle_injury_total += m[i]['부상자수']

print(Middle_accident_total/len(m)) # 평균 사고건수
print(Middle_death_total / len(m)) # 평균 사망자수
print(Middle_injury_total / len(m)) # 평균 부상자수
# Out:
# 55330.0
# 106.60886319845858
# 425.0
# 0.8188824662813102
# 76858.0
# 148.08863198458573

# %%
zero = [zero_accident_total/len(z), zero_death_total/len(z), zero_injury_total/len(z)]
middle = [Middle_accident_total/len(m), Middle_death_total/len(m), Middle_injury_total/len(m)]
high = [accident_total/len(h), death_total/len(h), injury_total/len(h)]

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
import platform 

#한글표시
if platform.system() == 'Windows': 
    matplotlib.rc('font', family='Malgun Gothic') 
elif platform.system() == 'Darwin': # Mac 
    matplotlib.rc('font', family='AppleGothic') 
else: #linux 
    matplotlib.rc('font', family='NanumGothic') 

# 그래프에 마이너스 표시가 되도록 변경 
matplotlib.rcParams['axes.unicode_minus'] = False

r = ['사고건수', '사망자수', '부상자수']
x = np.arange(len(zero)) # 그래프에 나타날 그룹형 막대의 개수
plt.figure(figsize=(13,13)) # 그래프의 사이즈
plt.bar(x-0.2, zero, label='강수량 = 0', width=0.2, color='skyblue') # 강수량이 0인데이터들을 막대로 나타낸다. label은 막대가 나타내는 데이터의 이름, width는 막대의 폭 color는 색상지정
plt.bar(x-0.0, middle, label='강수량 < 80', width=0.2, color='blue')
plt.bar(x+0.2, high, label='강수량 > 80', width=0.2, color='darkblue')
plt.title('강수량에 따른 평균 교통사고수', fontsize=20) # 그래프의 제목
plt.xticks(x, r, fontsize=15) # 여기서 r은 각 그룹형 막대그래프가 나타낼 데이터들의 이름
plt.ylabel('(평균 사고건수), (사망자,부상자 수)', fontsize=15) # y축이 무엇을 나타내는지 알려주기 위한 글을 적는 곳
plt.legend() # 각 막대 그래프가 어떤 데이터를 나타내는지 분류해서 보여줌
